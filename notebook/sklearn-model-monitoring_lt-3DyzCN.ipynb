# %% [markdown]
# # Monitor your ML Models using Watson OpenScale and WML on Cloud Pak for Data

# %% [markdown]
# ## 1. Setup the Notebook Environment

# %% [markdown]
# ## 1.1 Install the necessary packages

# %% [markdown]
# ### Watson OpenScale Python SDK

# %%
# !pip install ibm-ai-openscale

# %% [markdown]
# ### Scikit-learn version 0.20

# %%
# !pip install scikit-learn==0.20.3

# %% [markdown]
# ### Watson Machine Learning Python SDK

# %%
# !pip install --upgrade watson-machine-learning-client-V4==1.0.93 | tail -n 1

# %% [markdown]
# Restart the Notebook after Installing the required packages. By clicking on `Kernel>Restart`

# %% [markdown]
# ## 1.2 Import Packages

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn import preprocessing
from sklearn import svm, metrics
from scipy import sparse
from watson_machine_learning_client import WatsonMachineLearningAPIClient
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
import json
import ibm_db


import pandas as pd
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV

from ibm_ai_openscale import APIClient4ICP
from ibm_ai_openscale.engines import *
from ibm_ai_openscale.utils import *
from ibm_ai_openscale.supporting_classes import PayloadRecord, Feature
from ibm_ai_openscale.supporting_classes.enums import *

# %% [markdown]
# ## 2. Configuration

# %% [markdown]
# ### 2.1 Global Variables

# %%
MODEL_NAME="svc_classifier"
DEPLOYMENT_NAME="svc-deployment"
# Ensure you create a an empty Schema and store the name in this variable
SCHEMA_NAME="JLQ22844"

# Enter the Deployment Space you have associated project with 
dep_name="sklearn-deployment-space"

# %% [markdown]
# ### 2.2 Add Dataset
#
# Select the `Insert Pandas Dataframe` option, after selecting the below cell. Ensure the variable name is `df_data_1`

# %%
df_data_1 = pd.read_csv('/project_data/data_asset/Telco-Customer-Churn.csv')
df_data_1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2.3 Update your AIOS Credentials

# %%
WOS_CREDENTIALS={
    "url" : os.environ['RUNTIME_ENV_APSX_URL'],
    "username":"admin",
    "password":"password"
}

# %% [markdown]
# ### 2.4 Input your WML Credentials

# %%
import sys,os,os.path


WML_CREDENTIALS = {
"token": os.environ['USER_ACCESS_TOKEN'],
"instance_id" : "wml_local",
"url" : os.environ['RUNTIME_ENV_APSX_URL'],
"version": "3.0.0"
}

# %% [markdown]
# ### 2.5 Add your Db credentials
#
# #### These Db credentials are needed ONLY if you have NOT configured your `OpenScale Datamart`.

# %%
DATABASE_CREDENTIALS = {
    "hostname": "dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net",
    "username": "tzm22305",
    "password": "s2knhr3znx-c5s03",
    "port": 50000,
    "db": "BLUDB",
    
}

# %% [markdown]
# ## 3. Create the Customer Churn Model using Scikit-Learn

# %%
X=df_data_1.drop(['customerID', 'Churn'], axis=1)
y=df_data_1.loc[:, 'Churn']

# %%
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
'''Add a categorical transformer to your model pipeline. 
    You will need to add a label encoder into the model pipeline before storing it into WML '''

categorical_features = ["gender", "SeniorCitizen", "Partner", "Dependents", "PhoneService", "MultipleLines", "InternetService", "OnlineSecurity",
                        "OnlineBackup", "DeviceProtection", "TechSupport", "StreamingTV", "StreamingMovies", "Contract", "PaperlessBilling", "PaymentMethod"]
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features)])

# %%
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', svm.SVC(kernel='linear'))])

# %%
model = pipeline.fit(X_train,y_train)

# %%
from sklearn.metrics  import accuracy_score, classification_report
y_scores = model.predict(X_test)
print(accuracy_score(y_test, y_scores))
print(classification_report(y_test, y_scores))
# Out:
# 0.7808063600227144
#               precision    recall  f1-score   support
#
#           No       0.84      0.87      0.85      1298
#          Yes       0.60      0.52      0.56       463
#
#    micro avg       0.78      0.78      0.78      1761
#    macro avg       0.72      0.70      0.70      1761
# weighted avg       0.77      0.78      0.78      1761

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(max_depth=5, learning_rate=0.08, objective= 'binary:logistic',n_jobs=-1)

pipeline_xgb = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', xgb_model)])
model_xgb = pipeline_xgb.fit(X_train,y_train)
y_scores_xgb = pipeline_xgb.predict(X_test)
print(accuracy_score(y_test, y_scores_xgb))
print(classification_report(y_test, y_scores_xgb))
# Out:
# 0.7756956274843839
#               precision    recall  f1-score   support
#
#           No       0.83      0.88      0.85      1298
#          Yes       0.59      0.48      0.53       463
#
#    micro avg       0.78      0.78      0.78      1761
#    macro avg       0.71      0.68      0.69      1761
# weighted avg       0.76      0.78      0.77      1761

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=6, random_state=0)

pipeline_rf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', clf)])
model_rf = pipeline_rf.fit(X_train,y_train)
y_scores_rf = pipeline_rf.predict(X_test)
print(accuracy_score(y_test, y_scores_rf))
print(classification_report(y_test, y_scores_rf))
# Out:
# 0.7762634866553095
#               precision    recall  f1-score   support
#
#           No       0.82      0.89      0.85      1298
#          Yes       0.60      0.45      0.52       463
#
#    micro avg       0.78      0.78      0.78      1761
#    macro avg       0.71      0.67      0.69      1761
# weighted avg       0.76      0.78      0.77      1761

# %%
client = WatsonMachineLearningAPIClient(WML_CREDENTIALS)

# %%
meta_props={
 client.repository.ModelMetaNames.NAME: MODEL_NAME,
 client.repository.ModelMetaNames.RUNTIME_UID: "scikit-learn_0.20-py3.6",
 client.repository.ModelMetaNames.TYPE: "scikit-learn_0.20",
}

# %% [markdown]
# ## 4. Create a new Deployment Space

# %%
project_id = os.environ['PROJECT_ID']
client.set.default_project(project_id)
# Out:
# 'SUCCESS'

# %%
def guid_from_space_name(client, space_name):

    instance_details = client.service_instance.get_details()

    space = client.spaces.get_details()
    res=[]
    for item in space['resources']: 
        if item['entity']["name"] == space_name:
            res=item['metadata']['guid']

    return res

# %%
# Enter the name of your deployment space of the current project

space_uid = guid_from_space_name(client, dep_name)

# %%
space_uid
# Out:
# '0c9a4333-d89b-48f1-9c56-50fdc439e2ea'

# %%
client.set.default_space(space_uid)
# Out:
# Unsetting the project_id ...
# 'SUCCESS'

# %% [markdown]
# ### Store, Deploy and Score your Custom WML Model

# %%
deploy_meta = {
     client.deployments.ConfigurationMetaNames.NAME: DEPLOYMENT_NAME,
     client.deployments.ConfigurationMetaNames.ONLINE: {}
 }

# %%
## Store the model on WML
published_model = client.repository.store_model(pipeline,
                                             meta_props=meta_props,
                                             training_data=X_train,
                                             training_target=y_train
                                                )

# %%
published_model_uid = client.repository.get_model_uid(published_model)

# %%
## Create a Deployment for your stored model

created_deployment = client.deployments.create(published_model_uid, meta_props=deploy_meta)
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: 'f655e204-13ef-40d9-84d3-7f957eb9e9ee' started
#
# #######################################################################################
#
#
# initializing
# ready
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='0f430e90-d5ac-4610-8387-24e2b506a7aa'
# ------------------------------------------------------------------------------------------------

# %%
scoring_endpoint = None
deployment_uid=created_deployment['metadata']['guid']

# %% [markdown]
# ## 5. Setup your Watson Openscale Dashboard

# %% [markdown]
# ### 5.1 Create the Watson Openscale Client

# %%
ai_client = APIClient4ICP(aios_credentials=WOS_CREDENTIALS)
ai_client.version
# Out:
# '2.1.21'

# %% [markdown]
# ### 5.2 Setup the Datamart on AI OpenScale

# %%
try:
    data_mart_details = ai_client.data_mart.get_details()
    print('Using existing external datamart')
except:
    print('Setting up external datamart')
    ai_client.data_mart.setup(db_credentials=DATABASE_CREDENTIALS, schema=SCHEMA_NAME)
# Out:
# Using existing external datamart

# %%
data_mart_details = ai_client.data_mart.get_details()

# %%
data_mart_details
# Out:
# {'database_configuration': {'credentials': {'certificate_base64': None,
#    'db': 'BLUDB',
#    'hostname': 'dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net',
#    'password': '049t4-jst67cmw4c',
#    'port': 50000,
#    'ssl': False,
#    'username': 'jlq22844'},
#   'database_type': 'db2',
#   'instance_id': 'dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net',
#   'location': {'schema': 'JLQ22844'},
#   'name': 'manual-dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net'},
#  'internal_database': False,
#  'service_instance_crn': 'N/A',
#  'status': {'state': 'active'}}

# %% [markdown]
# ### 5.3 Add your Machine Learning Provider
#
# If you have already bound the ML Provider to the Openscale instance, then just retrieve the binding_uid, by commenting first line and uncommenting the second line

# %%
WML_CREDENTIALS
# Out:
# {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6ImFkbWluIiwic3ViIjoiYWRtaW4iLCJpc3MiOiJLTk9YU1NPIiwiYXVkIjoiRFNYIiwicm9sZSI6IkFkbWluIiwicGVybWlzc2lvbnMiOltdLCJ1aWQiOiIxMDAwMzMwOTk5IiwiaWF0IjoxNTk4Mjk4NTg4fQ.g0YYhuIX2vcYd7vBnLJcte2c2h4MeZ72Cl9lwQ80VgCGlWws0W3dhrJK3LjVQDzkko1xZVdsExJJyhp4YNj_lBnE6ulSUkmA8sOjCQl5iDygH371U6b5reJsowcU9vSS9xo6NT4ZsaI3rKg2KcaFMFgigNlbbI7oreq-tFDgkFJyblo4--AW4WULgCf5-R32XxrnAXbawWFgkjXcQFY3DpmsN4BBPfP4lqAJPBZEhkutXhQP9NfQK4-X-iszdcI1_HnJnIwj2pJzNlKlM0vSocsvYM98xbdEPakBMit7BvAoD8pSVKqZyIhyytHBGOSJYtXmfgAUwM3Yam9rhz1-FA',
#  'instance_id': 'wml_local',
#  'url': 'https://internal-nginx-svc:12443',
#  'version': '3.0.0'}

# %%
binding_uid = ai_client.data_mart.bindings.add('WML instance - sklearn', WatsonMachineLearningInstance4ICP(wml_credentials=WML_CREDENTIALS))

# %%
ai_client.data_mart.bindings.list_assets()
# Out:
# <HTML>
#         <body>
#             <h3>Available assets</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>source_uid</th><th style='border: 1px solid #dddddd'>name</th><th style='border: 1px solid #dddddd'>created</th><th style='border: 1px solid #dddddd'>type</th><th style='border: 1px solid #dddddd'>frameworks</th><th style='border: 1px solid #dddddd'>binding_uid</th><th style='border: 1px solid #dddddd'>is_subscribed</th>
#                 <tr><td style='border: 1px solid #dddddd'>f655e204-13ef-40d9-84d3-7f957eb9e9ee</td><td style='border: 1px solid #dddddd'>svc_classifier</td><td style='border: 1px solid #dddddd'>2020-08-25T18:39:36.002Z</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>scikit-learn_0.20</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>False</td></tr><tr><td style='border: 1px solid #dddddd'>fc9c8d9b-14d1-43aa-a0d4-f54339624e00</td><td style='border: 1px solid #dddddd'>sklearn_classifier</td><td style='border: 1px solid #dddddd'>2020-08-24T20:15:28.002Z</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>scikit-learn_0.20</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>False</td></tr><tr><td style='border: 1px solid #dddddd'>de2bb151-b048-4a8f-9945-ff57e5e8707b</td><td style='border: 1px solid #dddddd'>XGBoost_model</td><td style='border: 1px solid #dddddd'>2020-08-19T22:07:05.002Z</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>scikit-learn_0.22</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>False</td></tr><tr><td style='border: 1px solid #dddddd'>4cb08f0c-3159-4c35-9e34-ef671f1dc4de</td><td style='border: 1px solid #dddddd'>XGBosst_model</td><td style='border: 1px solid #dddddd'>2020-08-19T21:41:26.002Z</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>scikit-learn_0.22</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>False</td></tr><tr><td style='border: 1px solid #dddddd'>ef6123d2-edcd-4268-bdc3-e6948499e50d</td><td style='border: 1px solid #dddddd'>Tower 23</td><td style='border: 1px solid #dddddd'>2020-08-19T20:58:54.002Z</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>scikit-learn_0.20</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>False</td></tr><tr><td style='border: 1px solid #dddddd'>816e9a0f-d2ad-496d-bfc6-76cc22c16b42</td><td style='border: 1px solid #dddddd'>churn_deployment123</td><td style='border: 1px solid #dddddd'>2020-08-19T19:05:05.002Z</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>mllib_2.3</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>False</td></tr><tr><td style='border: 1px solid #dddddd'>8380a163-29ff-483e-b280-66b834ebb9c1</td><td style='border: 1px solid #dddddd'>churn_deployment</td><td style='border: 1px solid #dddddd'>2020-08-17T21:32:43.002Z</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>mllib_2.3</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>False</td></tr><tr><td style='border: 1px solid #dddddd'>511b15de-4c3d-4661-9429-1e7b086a4bdc</td><td style='border: 1px solid #dddddd'>churn_deployment</td><td style='border: 1px solid #dddddd'>2020-08-16T22:37:20.002Z</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>mllib_2.3</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>False</td></tr><tr><td style='border: 1px solid #dddddd'>ae59def3-a05b-4ba1-a3b8-20886dea737c</td><td style='border: 1px solid #dddddd'>Tower A</td><td style='border: 1px solid #dddddd'>2020-08-16T21:34:26.002Z</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>scikit-learn_0.20</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>Fa ...
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# ### 5.4 Perform Initial Scoring for your Model Deployment

# %%
score=X_test.tail(20)
score
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4160    Male              0      No         No      26          Yes
# 5340  Female              0      No         No      38          Yes
# 3242    Male              0      No        Yes       5          Yes
# 4540    Male              0      No         No       1          Yes
# 1427    Male              1      No         No      44          Yes
# 1255  Female              0      No         No       2           No
# 4008  Female              0     Yes        Yes      51           No
# 1668  Female              0      No         No      45          Yes
# 6615    Male              0      No        Yes       9          Yes
# 678     Male              0      No         No       3          Yes
# 3927    Male              0     Yes         No       3          Yes
# 918   Female              0      No         No      26          Yes
# 5809  Female              0      No         No       6          Yes
# 452     Male              0     Yes         No      60           No
# 3359    Male              0      No         No      21          Yes
# 3184  Female              0     Yes         No      71          Yes
# 2551  Female              0      No         No      12          Yes
# 5735  Female              0     Yes        Yes      48          Yes
# 5096    Male              0     Yes        Yes      71          Yes
# 450   Female              0      No         No      64          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 4160                No             DSL                  Yes
# 5340               Yes             DSL                  Yes
# 3242                No              No  No internet service
# 4540                No              No  No internet service
# 1427                No     Fiber optic                   No
# 1255  No phone service             DSL                   No
# 4008  No phone service             DSL                   No
# 1668               Yes     Fiber optic                  Yes
# 6615                No             DSL                   No
# 678                Yes     Fiber optic                   No
# 3927                No              No  No internet service
# 918                Yes     Fiber optic                   No
# 5809                No     Fiber optic                   No
# 452   No phone service             DSL                   No
# 3359                No              No  No internet service
# 3184               Yes             DSL                   No
# 2551                No              No  No internet service
# 5735                No              No  No internet service
# 5096               Yes             DSL                  Yes
# 450                Yes              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 4160                   No                   No                  Yes
# 5340                  Yes                  Yes                   No
# 3242  No internet service  No internet service  No internet service
# 4540  No internet service  No internet service  No internet service
# 1427                   No                  Yes                   No
# 1255                   No                   No                  Yes
# 4008                   No                  Yes                  Yes
# 1668                  Yes                  Yes                  Yes
# 6615                  Yes                   No                   No
# 678                   Yes                  Yes                   No
# 3927  No internet service  No internet service  No internet service
# 918                    No                  Yes                   No
# 5809                  Yes                   No                   No
# 452                   Yes                  Yes                  Yes
# 3359  No internet service  No internet service  No internet service
# 3184                  Yes                  Yes                  Yes
# 2551  No internet service  No internet service  No internet service
# 5735  No internet service  No internet service  No internet service
# 5096                  Yes                  Yes                  Yes
# 450   No internet service  No internet service  No internet service
#
#               StreamingTV      StreamingMovies        Contract  \
# 4160                  Yes                  Yes        One year
# 5340                  Yes                  Yes        One year
# 3242  No internet service  No internet service        Two year
# 4540  No internet service  No internet service  Month-to-month
# 1427                   No                   No  Month-to-month
# 1255                   No                   No  Month-to-month
# 4008                  Yes                  Yes        One year
# 1668                  Yes                  Yes  Month-to-month
# 6615                   No                   No  Month-to-month
# 678                   Yes                  Yes  Month-to-month
# 3927  No internet service  No internet service  Month-to-month
# 918                    No                   No  Month-to-month
# 5809                   No                  Yes  Month-to-month
# 452                   Yes                  Yes  Month-to-month
# 3359  No internet service  No internet service  Month-to-month
# 3184                  Yes                  Yes        Two year
# 2551  No internet service  No internet service  Month-to-month
# 5735  No internet service  No internet service        Two year
# 5096                  Yes                  Yes        Two year
# 450   No internet service  No internet service        One year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 4160               No  Bank transfer (automatic)           75.00      1908.35
# 5340               No  Bank transfer (automatic)           84.10      3187.65
# 3242               No               Mailed check           20.45        106.9
# 4540               No  Bank transfer (automatic)           20.95        20.95
# 1427               No           Electronic check           73.85       3122.4
# 1255              Yes           Electronic check           30.90        59.05
# 4008              Yes           Electronic check           56.15      2898.95
# 1668              Yes           Electronic check          115.65       5125.5
# 6615              Yes           Electronic check           50.10       484.05
# 678                No               Mailed check          107.95        313.6
# 3927              Yes    Credit card (automatic)           20.55        51.15
# 918               Yes           Electronic check           80.70         2193
# 5809              Yes               Mailed check           85.95        514.6
# 452               Yes  Bank transfer (automatic)           60.20       3582.4
# 3359              Yes               Mailed check           19.95        416.4
# 3184              Yes    Credit card (automatic)           83.30       5894.5
# 2551               No  Bank transfer (automatic)           19.45       227.45
# 5735               No               Mailed check           20.00        935.9
# 5096               No  Bank transfer (automatic)           86.85       6263.8
# 450                No               Mailed check           24.70      1642.75

# %%
scoring_data=list(list(x) for x in zip(*(score[x].values.tolist() for x in score.columns)))
scoring_data
# Out:
# [['Male',
#   0,
#   'No',
#   'No',
#   26,
#   'Yes',
#   'No',
#   'DSL',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'One year',
#   'No',
#   'Bank transfer (automatic)',
#   75.0,
#   '1908.35'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   38,
#   'Yes',
#   'Yes',
#   'DSL',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'One year',
#   'No',
#   'Bank transfer (automatic)',
#   84.1,
#   '3187.65'],
#  ['Male',
#   0,
#   'No',
#   'Yes',
#   5,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Two year',
#   'No',
#   'Mailed check',
#   20.45,
#   '106.9'],
#  ['Male',
#   0,
#   'No',
#   'No',
#   1,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Month-to-month',
#   'No',
#   'Bank transfer (automatic)',
#   20.95,
#   '20.95'],
#  ['Male',
#   1,
#   'No',
#   'No',
#   44,
#   'Yes',
#   'No',
#   'Fiber optic',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Month-to-month',
#   'No',
#   'Electronic check',
#   73.85,
#   '3122.4'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   2,
#   'No',
#   'No phone service',
#   'DSL',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Month-to-month',
#   'Yes',
#   'Electronic check',
#   30.9,
#   '59.05'],
#  ['Female',
#   0,
#   'Yes',
#   'Yes',
#   51,
#   'No',
#   'No phone service',
#   'DSL',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'One year',
#   'Yes',
#   'Electronic check',
#   56.15,
#   '2898.95'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   45,
#   'Yes',
#   'Yes',
#   'Fiber optic',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Month-to-month',
#   'Yes',
#   'Electronic check',
#   115.65,
#   '5125.5'],
#  ['Male',
#   0,
#   'No',
#   'Yes',
#   9,
#   'Yes',
#   'No',
#   'DSL',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Month-to-month',
#   'Yes',
#   'Electronic check',
#   50.1,
#   '484.05'],
#  ['Male',
#   0,
#   'No',
#   'No',
#   3,
#   'Yes',
#   'Yes',
#   'Fiber optic',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Month-to-month',
#   'No',
#   'Mailed check',
#   107.95,
#   '313.6'],
#  ['Male',
#   0,
#   'Yes',
#   'No',
#   3,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Month-to-month',
#   'Yes',
#   'Credit card (automatic)',
#   20.55,
#   '51.15'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   26,
#   'Yes',
#   'Yes',
#   'Fiber optic',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Month-to-month',
#   'Yes',
#   'Electronic check',
#   80.7,
#   '2193'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   6,
#   'Yes',
#   'No',
#   'Fiber optic',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Month-to-month',
#   'Yes',
#   'Mailed check',
#   85.95,
#   '514.6'],
#  ['Male',
#   0,
#   'Yes',
#   'No',
#   60,
#   'No',
#   'No phone service',
#   'DSL',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Month-to-month',
#   'Yes',
#   'Bank transfer (automatic)',
#   60.2,
#   '3582.4'],
#  ['Male',
#   0,
#   'No',
#   'No',
#   21,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Month-to-month',
#   'Yes',
#   'Mailed check',
#   19.95,
#   '416.4'],
#  ['Female',
#   0,
#   'Yes',
#   'No',
#   71,
#   'Yes',
#   'Yes',
#   'DSL',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Two year',
#   'Yes',
#   'Credit card (automatic)',
#   83.3,
#   '5894.5'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   12,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Month-to-month',
#   'No',
#   'Bank transfer (automatic)',
#   19.45,
#   '227.45'],
#  ['Female',
#   0,
#   'Yes',
#   'Yes',
#   48,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Two year',
#   'No',
#   'Mailed check',
#   20.0,
#   '935.9'],
#  ['Male',
#   0,
#   'Yes',
#   'Yes',
#   71,
#   'Yes',
#   'Yes',
#   'DSL',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Two year',
#   'No',
#   'Bank transfer (automatic)',
#   86.85,
#   '6263.8'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   64,
#   'Yes',
#   'Yes',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'One year',
#   'No',
#   'Mailed check',
#   24.7,
#   '1642.75']]

# %%
fields=list(X_test.columns)
print(len(fields))
fields, scoring_data[0]
# Out:
# 19
# (['gender',
#   'SeniorCitizen',
#   'Partner',
#   'Dependents',
#   'tenure',
#   'PhoneService',
#   'MultipleLines',
#   'InternetService',
#   'OnlineSecurity',
#   'OnlineBackup',
#   'DeviceProtection',
#   'TechSupport',
#   'StreamingTV',
#   'StreamingMovies',
#   'Contract',
#   'PaperlessBilling',
#   'PaymentMethod',
#   'MonthlyCharges',
#   'TotalCharges'],
#  ['Male',
#   0,
#   'No',
#   'No',
#   26,
#   'Yes',
#   'No',
#   'DSL',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'One year',
#   'No',
#   'Bank transfer (automatic)',
#   75.0,
#   '1908.35'])

# %%
job_payload = {
client.deployments.ScoringMetaNames.INPUT_DATA: [{
 'values': scoring_data
}]
}
print(job_payload)
# Out:
# {'input_data': [{'values': [['Male', 0, 'No', 'No', 26, 'Yes', 'No', 'DSL', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'One year', 'No', 'Bank transfer (automatic)', 75.0, '1908.35'], ['Female', 0, 'No', 'No', 38, 'Yes', 'Yes', 'DSL', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'One year', 'No', 'Bank transfer (automatic)', 84.1, '3187.65'], ['Male', 0, 'No', 'Yes', 5, 'Yes', 'No', 'No', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'Two year', 'No', 'Mailed check', 20.45, '106.9'], ['Male', 0, 'No', 'No', 1, 'Yes', 'No', 'No', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'Month-to-month', 'No', 'Bank transfer (automatic)', 20.95, '20.95'], ['Male', 1, 'No', 'No', 44, 'Yes', 'No', 'Fiber optic', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Month-to-month', 'No', 'Electronic check', 73.85, '3122.4'], ['Female', 0, 'No', 'No', 2, 'No', 'No phone service', 'DSL', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Month-to-month', 'Yes', 'Electronic check', 30.9, '59.05'], ['Female', 0, 'Yes', 'Yes', 51, 'No', 'No phone service', 'DSL', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'One year', 'Yes', 'Electronic check', 56.15, '2898.95'], ['Female', 0, 'No', 'No', 45, 'Yes', 'Yes', 'Fiber optic', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Month-to-month', 'Yes', 'Electronic check', 115.65, '5125.5'], ['Male', 0, 'No', 'Yes', 9, 'Yes', 'No', 'DSL', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Month-to-month', 'Yes', 'Electronic check', 50.1, '484.05'], ['Male', 0, 'No', 'No', 3, 'Yes', 'Yes', 'Fiber optic', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Month-to-month', 'No', 'Mailed check', 107.95, '313.6'], ['Male', 0, 'Yes', 'No', 3, 'Yes', 'No', 'No', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'Month-to-month', 'Yes', 'Credit card (automatic)', 20.55, '51.15'], ['Female', 0, 'No', 'No', 26, 'Yes', 'Yes', 'Fiber optic', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Month-to-month', 'Yes', 'Electronic check', 80.7, '2193'], ['Female', 0, 'No', 'No', 6, 'Yes', 'No', 'Fiber optic', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'Month-to-month', 'Yes', 'Mailed check', 85.95, '514.6'], ['Male', 0, 'Yes', 'No', 60, 'No', 'No phone service', 'DSL', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Month-to-month', 'Yes', 'Bank transfer (automatic)', 60.2, '3582.4'], ['Male', 0, 'No', 'No', 21, 'Yes', 'No', 'No', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'Month-to-month', 'Yes', 'Mailed check', 19.95, '416.4'], ['Female', 0, 'Yes', 'No', 71, 'Yes', 'Yes', 'DSL', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Two year', 'Yes', 'Credit card (automatic)', 83.3, '5894.5'], ['Female', 0, 'No', 'No', 12, 'Yes', 'No', 'No', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'Month-to-month', 'No', 'Bank transfer (automatic)', 19.45, '227.45'], ['Female', 0, 'Yes', 'Yes', 48, 'Yes', 'No', 'No', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'Two year', 'No', 'Mailed check', 20.0, '935.9'], ['Male', 0, 'Yes', 'Yes', 71, 'Yes', 'Yes', 'DSL', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Two year', 'No', 'Bank transfer (automatic)', 86.85, '6263.8'], ['Female', 0, 'No', 'No', 64, 'Yes', 'Yes', 'No', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'No internet service', 'One year', 'No', 'Mailed check', 24.7, '1642.75']]}]}

# %%
scoring_response = client.deployments.score(deployment_uid, job_payload)

print(scoring_response)
# Out:
# {'predictions': [{'fields': ['prediction'], 'values': [['No'], ['No'], ['No'], ['No'], ['Yes'], ['No'], ['No'], ['No'], ['No'], ['No'], ['No'], ['Yes'], ['Yes'], ['No'], ['No'], ['No'], ['No'], ['No'], ['No'], ['No']]}]}

# %% [markdown]
# ### 5.5 Create a new Subscription

# %%
subscription = ai_client.data_mart.subscriptions.add(WatsonMachineLearningAsset(
    published_model_uid,
    problem_type=ProblemType.BINARY_CLASSIFICATION,
    input_data_type=InputDataType.STRUCTURED,
    label_column='Churn',
    prediction_column='prediction',
    probability_column='prediction_probability',
    categorical_columns=["gender", "SeniorCitizen", "Partner", "Dependents", "PhoneService", "MultipleLines", "InternetService", "OnlineSecurity",
                        "OnlineBackup", "DeviceProtection", "TechSupport", "StreamingTV", "StreamingMovies", "Contract", "PaperlessBilling", "PaymentMethod"],
    feature_columns = ["gender", "SeniorCitizen", "Partner", "Dependents", "PhoneService", "MultipleLines", "InternetService", "OnlineSecurity",
                        "OnlineBackup", "DeviceProtection", "TechSupport", "StreamingTV", "StreamingMovies", "Contract", "PaperlessBilling", "PaymentMethod", "tenure","TotalCharges","MonthlyCharges"],
))

# %%
subscriptions_uids = ai_client.data_mart.subscriptions.get_uids()
ai_client.data_mart.subscriptions.list()
# Out:
# <HTML>
#         <body>
#             <h3>Subscriptions</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>uid</th><th style='border: 1px solid #dddddd'>name</th><th style='border: 1px solid #dddddd'>type</th><th style='border: 1px solid #dddddd'>binding_uid</th><th style='border: 1px solid #dddddd'>created</th>
#                 <tr><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>svc_classifier</td><td style='border: 1px solid #dddddd'>model</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>2020-08-25T18:40:22.820Z</td></tr>
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# ### 5.6 Perform Inital Payload Logging
# Note: You may re-use this code snippet by modifying the request_data variable to perform payload logging after finishing the initial dashboard setup

# %%
fields=list(X_test.columns)

request_data = {
    "fields": fields,
    "values": scoring_data
  }
request_data
# Out:
# {'fields': ['gender',
#   'SeniorCitizen',
#   'Partner',
#   'Dependents',
#   'tenure',
#   'PhoneService',
#   'MultipleLines',
#   'InternetService',
#   'OnlineSecurity',
#   'OnlineBackup',
#   'DeviceProtection',
#   'TechSupport',
#   'StreamingTV',
#   'StreamingMovies',
#   'Contract',
#   'PaperlessBilling',
#   'PaymentMethod',
#   'MonthlyCharges',
#   'TotalCharges'],
#  'values': [['Male',
#    0,
#    'No',
#    'No',
#    26,
#    'Yes',
#    'No',
#    'DSL',
#    'Yes',
#    'No',
#    'No',
#    'Yes',
#    'Yes',
#    'Yes',
#    'One year',
#    'No',
#    'Bank transfer (automatic)',
#    75.0,
#    '1908.35'],
#   ['Female',
#    0,
#    'No',
#    'No',
#    38,
#    'Yes',
#    'Yes',
#    'DSL',
#    'Yes',
#    'Yes',
#    'Yes',
#    'No',
#    'Yes',
#    'Yes',
#    'One year',
#    'No',
#    'Bank transfer (automatic)',
#    84.1,
#    '3187.65'],
#   ['Male',
#    0,
#    'No',
#    'Yes',
#    5,
#    'Yes',
#    'No',
#    'No',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'Two year',
#    'No',
#    'Mailed check',
#    20.45,
#    '106.9'],
#   ['Male',
#    0,
#    'No',
#    'No',
#    1,
#    'Yes',
#    'No',
#    'No',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'Month-to-month',
#    'No',
#    'Bank transfer (automatic)',
#    20.95,
#    '20.95'],
#   ['Male',
#    1,
#    'No',
#    'No',
#    44,
#    'Yes',
#    'No',
#    'Fiber optic',
#    'No',
#    'No',
#    'Yes',
#    'No',
#    'No',
#    'No',
#    'Month-to-month',
#    'No',
#    'Electronic check',
#    73.85,
#    '3122.4'],
#   ['Female',
#    0,
#    'No',
#    'No',
#    2,
#    'No',
#    'No phone service',
#    'DSL',
#    'No',
#    'No',
#    'No',
#    'Yes',
#    'No',
#    'No',
#    'Month-to-month',
#    'Yes',
#    'Electronic check',
#    30.9,
#    '59.05'],
#   ['Female',
#    0,
#    'Yes',
#    'Yes',
#    51,
#    'No',
#    'No phone service',
#    'DSL',
#    'No',
#    'No',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'One year',
#    'Yes',
#    'Electronic check',
#    56.15,
#    '2898.95'],
#   ['Female',
#    0,
#    'No',
#    'No',
#    45,
#    'Yes',
#    'Yes',
#    'Fiber optic',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Month-to-month',
#    'Yes',
#    'Electronic check',
#    115.65,
#    '5125.5'],
#   ['Male',
#    0,
#    'No',
#    'Yes',
#    9,
#    'Yes',
#    'No',
#    'DSL',
#    'No',
#    'Yes',
#    'No',
#    'No',
#    'No',
#    'No',
#    'Month-to-month',
#    'Yes',
#    'Electronic check',
#    50.1,
#    '484.05'],
#   ['Male',
#    0,
#    'No',
#    'No',
#    3,
#    'Yes',
#    'Yes',
#    'Fiber optic',
#    'No',
#    'Yes',
#    'Yes',
#    'No',
#    'Yes',
#    'Yes',
#    'Month-to-month',
#    'No',
#    'Mailed check',
#    107.95,
#    '313.6'],
#   ['Male',
#    0,
#    'Yes',
#    'No',
#    3,
#    'Yes',
#    'No',
#    'No',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'Month-to-month',
#    'Yes',
#    'Credit card (automatic)',
#    20.55,
#    '51.15'],
#   ['Female',
#    0,
#    'No',
#    'No',
#    26,
#    'Yes',
#    'Yes',
#    'Fiber optic',
#    'No',
#    'No',
#    'Yes',
#    'No',
#    'No',
#    'No',
#    'Month-to-month',
#    'Yes',
#    'Electronic check',
#    80.7,
#    '2193'],
#   ['Female',
#    0,
#    'No',
#    'No',
#    6,
#    'Yes',
#    'No',
#    'Fiber optic',
#    'No',
#    'Yes',
#    'No',
#    'No',
#    'No',
#    'Yes',
#    'Month-to-month',
#    'Yes',
#    'Mailed check',
#    85.95,
#    '514.6'],
#   ['Male',
#    0,
#    'Yes',
#    'No',
#    60,
#    'No',
#    'No phone service',
#    'DSL',
#    'No',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Month-to-month',
#    'Yes',
#    'Bank transfer (automatic)',
#    60.2,
#    '3582.4'],
#   ['Male',
#    0,
#    'No',
#    'No',
#    21,
#    'Yes',
#    'No',
#    'No',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'Month-to-month',
#    'Yes',
#    'Mailed check',
#    19.95,
#    '416.4'],
#   ['Female',
#    0,
#    'Yes',
#    'No',
#    71,
#    'Yes',
#    'Yes',
#    'DSL',
#    'No',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Two year',
#    'Yes',
#    'Credit card (automatic)',
#    83.3,
#    '5894.5'],
#   ['Female',
#    0,
#    'No',
#    'No',
#    12,
#    'Yes',
#    'No',
#    'No',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'Month-to-month',
#    'No',
#    'Bank transfer (automatic)',
#    19.45,
#    '227.45'],
#   ['Female',
#    0,
#    'Yes',
#    'Yes',
#    48,
#    'Yes',
#    'No',
#    'No',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'Two year',
#    'No',
#    'Mailed check',
#    20.0,
#    '935.9'],
#   ['Male',
#    0,
#    'Yes',
#    'Yes',
#    71,
#    'Yes',
#    'Yes',
#    'DSL',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Yes',
#    'Two year',
#    'No',
#    'Bank transfer (automatic)',
#    86.85,
#    '6263.8'],
#   ['Female',
#    0,
#    'No',
#    'No',
#    64,
#    'Yes',
#    'Yes',
#    'No',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'No internet service',
#    'One year',
#    'No',
#    'Mailed check',
#    24.7,
#    '1642.75']]}

# %% [markdown]
# **<font color='red'><< REPLACE subscription_uid BELOW with the uid for your subscription. For e.g.<br/>subscription_uid="644e4e6d-8a82-4f07-9489-381d44469a23" >></font>**

# %%
## From the output of the above table choose your model name and copy the uid against it. Store the uid in the subscription_uid variable


subscription_uid="ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4"
from ibm_ai_openscale import APIClient4ICP
from ibm_ai_openscale.supporting_classes import PayloadRecord


subscription = ai_client.data_mart.subscriptions.get(subscription_uid=subscription_uid)


records = [PayloadRecord(request=request_data, response=scoring_response, response_time=18), 
                PayloadRecord(request=request_data, response=scoring_response, response_time=12)]

subscription.payload_logging.store(records=records)

# %% [markdown]
# ### 5.7 Setup Quality Monitoring
#
# ```NOTE: If you are using the dataset provided in the dashboard, leave the threshold monitors to these values. However, if you are using your own dataset, you can play around with the threshold value (value b/w 0 and 1) according to your requirement.```

# %%
time.sleep(5)
subscription.quality_monitoring.enable(threshold=0.95, min_records=5)

# %% [markdown]
# ### 5.8 Log Feedback Data to your Subscription

# %%
feedback_data_raw=pd.concat([X_test,y_test],axis=1)
feedback_data_raw
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2200  Female              0      No         No      19          Yes
# 4627    Male              0      No         No      60          Yes
# 3225  Female              0      No         No      13          Yes
# 2828    Male              0      No         No       1          Yes
# 3768  Female              0     Yes         No      55          Yes
# 4446    Male              1      No         No       3          Yes
# 2234    Male              0     Yes        Yes      23          Yes
# 5454  Female              1     Yes         No       1          Yes
# 1278    Male              0     Yes        Yes      36           No
# 578     Male              1     Yes         No      35          Yes
# 5960  Female              1      No         No      62          Yes
# 521     Male              1     Yes         No      29          Yes
# 217     Male              0     Yes         No      66           No
# 5716    Male              0      No        Yes       2          Yes
# 202     Male              0     Yes        Yes      71          Yes
# 134     Male              0      No         No       2          Yes
# 154   Female              0     Yes        Yes       6          Yes
# 4486  Female              0      No         No      61          Yes
# 3283  Female              0     Yes        Yes      69          Yes
# 3731    Male              0      No         No       2          Yes
# 2572  Female              0     Yes         No      71          Yes
# 4296  Female              0     Yes        Yes      35          Yes
# 2838  Female              0      No         No      41          Yes
# 3711  Female              0     Yes        Yes      55          Yes
# 2425    Male              0      No         No      26          Yes
# 5721  Female              0      No         No      27          Yes
# 6429    Male              0     Yes        Yes      67          Yes
# 5458    Male              0      No         No       7          Yes
# 5549  Female              0      No         No       3          Yes
# 6258  Female              0     Yes         No       3          Yes
# ...      ...            ...     ...        ...     ...          ...
# 2967    Male              0     Yes         No      59          Yes
# 3608    Male              0      No         No      39          Yes
# 496     Male              0     Yes         No      28          Yes
# 1037  Female              0      No         No      13           No
# 2346  Female              0     Yes        Yes      71          Yes
# 2570    Male              0     Yes         No      30          Yes
# 1484  Female              1     Yes         No      71          Yes
# 825   Female              0     Yes        Yes      16          Yes
# 3297  Female              0     Yes         No      42          Yes
# 3669    Male              0      No         No      44          Yes
# 4160    Male              0      No         No      26          Yes
# 5340  Female              0      No         No      38          Yes
# 3242    Male              0      No        Yes       5          Yes
# 4540    Male              0      No         No       1          Yes
# 1427    Male              1      No         No      44          Yes
# 1255  Female              0      No         No       2           No
# 4008  Female              0     Yes        Yes      51           No
# 1668  Female              0      No         No      45          Yes
# 6615    Male              0      No        Yes       9          Yes
# 678     Male              0      No         No       3          Yes
# 3927    Male              0     Yes         No       3          Yes
# 918   Female              0      No         No      26          Yes
# 5809  Female              0      No         No       6          Yes
# 452     Male              0     Yes         No      60           No
# 3359    Male              0      No         No      21          Yes
# 3184  Female              0     Yes         No      71          Yes
# 2551  Female              0      No         No      12          Yes
# 5735  Female              0     Yes        Yes      48          Yes
# 5096    Male              0     Yes        Yes      71          Yes
# 450   Female              0      No         No      64          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 2200                No             DSL                   No
# 4627               Yes     Fiber optic                  Yes
# 3225                No             DSL                  Yes
# 2828                No              No  No internet service
# 3768               Yes     Fiber optic                   No
# 4446                No     Fiber optic                   No
# 2234               Yes             DSL                   No
# 5454                No     Fiber optic                   No
# 1278  No phone service             DSL                  Yes
# 578                Yes     Fiber optic                  Yes
# 5960               Yes     Fiber optic                   No
# 521                Yes             DSL                   No
# 217   No phone service             DSL                  Yes
# 5716                No             DSL                   No
# 202                Yes     Fiber optic                  Yes
# 134                 No             DSL                   No
# 154                 No              No  No internet service
# 4486               Yes     Fiber optic                   No
# 3283                No              No  No internet service
# 3731                No     Fiber optic                   No
# 2572               Yes              No  No internet service
# 4296               Yes             DSL                  Yes
# 2838                No              No  No internet service
# 3711               Yes             DSL                  Yes
# 2425                No              No  No internet service
# 5721                No             DSL                  Yes
# 6429               Yes             DSL                  Yes
# 5458                No             DSL                  Yes
# 5549                No     Fiber optic                   No
# 6258                No              No  No internet service
# ...                ...             ...                  ...
# 2967               Yes     Fiber optic                  Yes
# 3608               Yes     Fiber optic                   No
# 496                 No             DSL                  Yes
# 1037  No phone service             DSL                   No
# 2346               Yes     Fiber optic                   No
# 2570               Yes     Fiber optic                   No
# 1484                No     Fiber optic                   No
# 825                 No     Fiber optic                   No
# 3297               Yes             DSL                  Yes
# 3669               Yes     Fiber optic                  Yes
# 4160                No             DSL                  Yes
# 5340               Yes             DSL                  Yes
# 3242                No              No  No internet service
# 4540                No              No  No internet service
# 1427                No     Fiber optic                   No
# 1255  No phone service             DSL                   No
# 4008  No phone service             DSL                   No
# 1668               Yes     Fiber optic                  Yes
# 6615                No             DSL                   No
# 678                Yes     Fiber optic                   No
# 3927                No              No  No internet service
# 918                Yes     Fiber optic                   No
# 5809                No     Fiber optic                   No
# 452   No phone service             DSL                   No
# 3359                No              No  No internet service
# 3184               Yes             DSL                   No
# 2551                No              No  No internet service
# 5735                No              No  No internet service
# 5096               Yes             DSL                  Yes
# 450                Yes              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 2200                  Yes                   No                   No
# 4627                  Yes                  Yes                  Yes
# 3225                   No                   No                   No
# 2828  No internet service  No internet service  No internet service
# 3768                  Yes                   No                   No
# 4446                   No                   No                   No
# 2234                  Yes                   No                  Yes
# 5454                   No                   No                   No
# 1278                   No                  Yes                  Yes
# 578                   Yes                   No                   No
# 5960                   No                   No                   No
# 521                    No                   No                   No
# 217                   Yes                  Yes                  Yes
# 5716                   No                   No                   No
# 202                    No                  Yes                   No
# 134                    No                   No                   No
# 154   No internet service  No internet service  No internet service
# 4486                   No                  Yes                   No
# 3283  No internet service  No internet service  No internet service
# 3731                   No                   No                   No
# 2572  No internet service  No internet service  No internet service
# 4296                   No                  Yes                  Yes
# 2838  No internet service  No internet service  No internet service
# 3711                  Yes                   No                  Yes
# 2425  No internet service  No internet service  No internet service
# 5721                  Yes                   No                   No
# 6429                  Yes                  Yes                  Yes
# 5458                   No                   No                   No
# 5549                  Yes                   No                  Yes
# 6258  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 2967                  Yes                  Yes                  Yes
# 3608                   No                   No                   No
# 496                   Yes                   No                  Yes
# 1037                   No                  Yes                   No
# 2346                  Yes                  Yes                   No
# 2570                   No                   No                   No
# 1484                  Yes                  Yes                   No
# 825                   Yes                  Yes                   No
# 3297                   No                  Yes                  Yes
# 3669                  Yes                  Yes                   No
# 4160                   No                   No                  Yes
# 5340                  Yes                  Yes                   No
# 3242  No internet service  No internet service  No internet service
# 4540  No internet service  No internet service  No internet service
# 1427                   No                  Yes                   No
# 1255                   No                   No                  Yes
# 4008                   No                  Yes                  Yes
# 1668                  Yes                  Yes                  Yes
# 6615                  Yes                   No                   No
# 678                   Yes                  Yes                   No
# 3927  No internet service  No internet service  No internet service
# 918                    No                  Yes                   No
# 5809                  Yes                   No                   No
# 452                   Yes                  Yes                  Yes
# 3359  No internet service  No internet service  No internet service
# 3184                  Yes                  Yes                  Yes
# 2551  No internet service  No internet service  No internet service
# 5735  No internet service  No internet service  No internet service
# 5096                  Yes                  Yes                  Yes
# 450   No internet service  No internet service  No internet service
#
#               StreamingTV      StreamingMovies        Contract  \
# 2200                  Yes                   No        One year
# 4627                  Yes                  Yes        One year
# 3225                  Yes                  Yes  Month-to-month
# 2828  No internet service  No internet service        Two year
# 3768                   No                   No  Month-to-month
# 4446                  Yes                   No  Month-to-month
# 2234                   No                   No        Two year
# 5454                   No                   No  Month-to-month
# 1278                  Yes                  Yes        One year
# 578                    No                  Yes  Month-to-month
# 5960                  Yes                   No        One year
# 521                    No                   No  Month-to-month
# 217                   Yes                   No        Two year
# 5716                   No                  Yes  Month-to-month
# 202                   Yes                  Yes        Two year
# 134                    No                   No  Month-to-month
# 154   No internet service  No internet service  Month-to-month
# 4486                   No                  Yes  Month-to-month
# 3283  No internet service  No internet service        One year
# 3731                   No                   No  Month-to-month
# 2572  No internet service  No internet service        Two year
# 4296                  Yes                   No  Month-to-month
# 2838  No internet service  No internet service        Two year
# 3711                   No                  Yes        One year
# 2425  No internet service  No internet service  Month-to-month
# 5721                   No                   No        Two year
# 6429                   No                   No        One year
# 5458                   No                   No  Month-to-month
# 5549                  Yes                  Yes  Month-to-month
# 6258  No internet service  No internet service  Month-to-month
# ...                   ...                  ...             ...
# 2967                  Yes                  Yes        Two year
# 3608                   No                   No  Month-to-month
# 496                    No                   No  Month-to-month
# 1037                  Yes                  Yes  Month-to-month
# 2346                   No                  Yes        Two year
# 2570                  Yes                  Yes  Month-to-month
# 1484                  Yes                  Yes        Two year
# 825                   Yes                   No  Month-to-month
# 3297                  Yes                  Yes        Two year
# 3669                  Yes                  Yes  Month-to-month
# 4160                  Yes                  Yes        One year
# 5340                  Yes                  Yes        One year
# 3242  No internet service  No internet service        Two year
# 4540  No internet service  No internet service  Month-to-month
# 1427                   No                   No  Month-to-month
# 1255                   No                   No  Month-to-month
# 4008                  Yes                  Yes        One year
# 1668                  Yes                  Yes  Month-to-month
# 6615                   No                   No  Month-to-month
# 678                   Yes                  Yes  Month-to-month
# 3927  No internet service  No internet service  Month-to-month
# 918                    No                   No  Month-to-month
# 5809                   No                  Yes  Month-to-month
# 452                   Yes                  Yes  Month-to-month
# 3359  No internet service  No internet service  Month-to-month
# 3184                  Yes                  Yes        Two year
# 2551  No internet service  No internet service  Month-to-month
# 5735  No internet service  No internet service        Two year
# 5096                  Yes                  Yes        Two year
# 450   No internet service  No internet service        One year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 2200               No           Electronic check           58.20      1045.25
# 4627              Yes    Credit card (automatic)          116.60       7049.5
# 3225              Yes           Electronic check           71.95       923.85
# 2828               No               Mailed check           20.45        20.45
# 3768              Yes    Credit card (automatic)           77.75       4266.4
# 4446              Yes           Electronic check           79.90        260.9
# 2234               No               Mailed check           59.70       1414.2
# 5454              Yes           Electronic check           69.55        69.55
# 1278               No    Credit card (automatic)           60.70      2234.55
# 578               Yes           Electronic check           94.55       3365.4
# 5960               No           Electronic check           84.45      4959.15
# 521               Yes           Electronic check           51.60         1442
# 217               Yes  Bank transfer (automatic)           56.60       3789.2
# 5716              Yes           Electronic check           55.30       108.65
# 202                No           Electronic check          105.55       7405.5
# 134                No           Electronic check           44.35        81.25
# 154                No               Mailed check           19.70        113.5
# 4486               No               Mailed check           89.20       5500.6
# 3283              Yes    Credit card (automatic)           20.35      1442.65
# 3731              Yes           Electronic check           69.80       146.65
# 2572               No  Bank transfer (automatic)           25.00         1753
# 4296               No           Electronic check           72.25      2568.55
# 2838               No               Mailed check           20.00        810.3
# 3711              Yes  Bank transfer (automatic)           75.75      4264.25
# 2425              Yes           Electronic check           20.30       511.25
# 5721               No  Bank transfer (automatic)           52.85      1498.65
# 6429              Yes    Credit card (automatic)           69.35      4653.25
# 5458              Yes               Mailed check           51.00       354.05
# 5549              Yes           Electronic check           97.90        315.3
# 6258              Yes               Mailed check           19.90        45.75
# ...               ...                        ...             ...          ...
# 2967               No           Electronic check          113.75      6561.25
# 3608               No           Electronic check           75.25      3017.65
# 496                No               Mailed check           60.90      1785.65
# 1037               No           Electronic check           49.15        649.4
# 2346              Yes    Credit card (automatic)           95.75       6849.4
# 2570              Yes    Credit card (automatic)           94.05      2866.45
# 1484              Yes           Electronic check           99.20      7213.75
# 825               Yes    Credit card (automatic)           89.45      1430.25
# 3297               No    Credit card (automatic)           84.35       3571.6
# 3669              Yes           Electronic check          111.50      4915.15
# 4160               No  Bank transfer (automatic)           75.00      1908.35
# 5340               No  Bank transfer (automatic)           84.10      3187.65
# 3242               No               Mailed check           20.45        106.9
# 4540               No  Bank transfer (automatic)           20.95        20.95
# 1427               No           Electronic check           73.85       3122.4
# 1255              Yes           Electronic check           30.90        59.05
# 4008              Yes           Electronic check           56.15      2898.95
# 1668              Yes           Electronic check          115.65       5125.5
# 6615              Yes           Electronic check           50.10       484.05
# 678                No               Mailed check          107.95        313.6
# 3927              Yes    Credit card (automatic)           20.55        51.15
# 918               Yes           Electronic check           80.70         2193
# 5809              Yes               Mailed check           85.95        514.6
# 452               Yes  Bank transfer (automatic)           60.20       3582.4
# 3359              Yes               Mailed check           19.95        416.4
# 3184              Yes    Credit card (automatic)           83.30       5894.5
# 2551               No  Bank transfer (automatic)           19.45       227.45
# 5735               No               Mailed check           20.00        935.9
# 5096               No  Bank transfer (automatic)           86.85       6263.8
# 450                No               Mailed check           24.70      1642.75
#
#      Churn
# 2200    No
# 4627    No
# 3225    No
# 2828    No
# 3768    No
# 4446   Yes
# 2234    No
# 5454   Yes
# 1278    No
# 578     No
# 5960    No
# 521     No
# 217     No
# 5716    No
# 202     No
# 134    Yes
# 154     No
# 4486    No
# 3283    No
# 3731    No
# 2572    No
# 4296   Yes
# 2838    No
# 3711    No
# 2425    No
# 5721    No
# 6429    No
# 5458   Yes
# 5549   Yes
# 6258    No
# ...    ...
# 2967    No
# 3608   Yes
# 496     No
# 1037    No
# 2346    No
# 2570   Yes
# 1484    No
# 825    Yes
# 3297    No
# 3669    No
# 4160    No
# 5340    No
# 3242    No
# 4540    No
# 1427    No
# 1255   Yes
# 4008    No
# 1668    No
# 6615    No
# 678     No
# 3927   Yes
# 918     No
# 5809    No
# 452     No
# 3359    No
# 3184    No
# 2551    No
# 5735    No
# 5096    No
# 450     No
#
# [1761 rows x 20 columns]

# %%
feedback_data=feedback_data_raw.tail(20).values.tolist()
feedback_data
# Out:
# [['Male',
#   0,
#   'No',
#   'No',
#   26,
#   'Yes',
#   'No',
#   'DSL',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'One year',
#   'No',
#   'Bank transfer (automatic)',
#   75.0,
#   '1908.35',
#   'No'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   38,
#   'Yes',
#   'Yes',
#   'DSL',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'One year',
#   'No',
#   'Bank transfer (automatic)',
#   84.1,
#   '3187.65',
#   'No'],
#  ['Male',
#   0,
#   'No',
#   'Yes',
#   5,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Two year',
#   'No',
#   'Mailed check',
#   20.45,
#   '106.9',
#   'No'],
#  ['Male',
#   0,
#   'No',
#   'No',
#   1,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Month-to-month',
#   'No',
#   'Bank transfer (automatic)',
#   20.95,
#   '20.95',
#   'No'],
#  ['Male',
#   1,
#   'No',
#   'No',
#   44,
#   'Yes',
#   'No',
#   'Fiber optic',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Month-to-month',
#   'No',
#   'Electronic check',
#   73.85,
#   '3122.4',
#   'No'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   2,
#   'No',
#   'No phone service',
#   'DSL',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Month-to-month',
#   'Yes',
#   'Electronic check',
#   30.9,
#   '59.05',
#   'Yes'],
#  ['Female',
#   0,
#   'Yes',
#   'Yes',
#   51,
#   'No',
#   'No phone service',
#   'DSL',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'One year',
#   'Yes',
#   'Electronic check',
#   56.15,
#   '2898.95',
#   'No'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   45,
#   'Yes',
#   'Yes',
#   'Fiber optic',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Month-to-month',
#   'Yes',
#   'Electronic check',
#   115.65,
#   '5125.5',
#   'No'],
#  ['Male',
#   0,
#   'No',
#   'Yes',
#   9,
#   'Yes',
#   'No',
#   'DSL',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Month-to-month',
#   'Yes',
#   'Electronic check',
#   50.1,
#   '484.05',
#   'No'],
#  ['Male',
#   0,
#   'No',
#   'No',
#   3,
#   'Yes',
#   'Yes',
#   'Fiber optic',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Month-to-month',
#   'No',
#   'Mailed check',
#   107.95,
#   '313.6',
#   'No'],
#  ['Male',
#   0,
#   'Yes',
#   'No',
#   3,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Month-to-month',
#   'Yes',
#   'Credit card (automatic)',
#   20.55,
#   '51.15',
#   'Yes'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   26,
#   'Yes',
#   'Yes',
#   'Fiber optic',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Month-to-month',
#   'Yes',
#   'Electronic check',
#   80.7,
#   '2193',
#   'No'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   6,
#   'Yes',
#   'No',
#   'Fiber optic',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Month-to-month',
#   'Yes',
#   'Mailed check',
#   85.95,
#   '514.6',
#   'No'],
#  ['Male',
#   0,
#   'Yes',
#   'No',
#   60,
#   'No',
#   'No phone service',
#   'DSL',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Month-to-month',
#   'Yes',
#   'Bank transfer (automatic)',
#   60.2,
#   '3582.4',
#   'No'],
#  ['Male',
#   0,
#   'No',
#   'No',
#   21,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Month-to-month',
#   'Yes',
#   'Mailed check',
#   19.95,
#   '416.4',
#   'No'],
#  ['Female',
#   0,
#   'Yes',
#   'No',
#   71,
#   'Yes',
#   'Yes',
#   'DSL',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Two year',
#   'Yes',
#   'Credit card (automatic)',
#   83.3,
#   '5894.5',
#   'No'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   12,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Month-to-month',
#   'No',
#   'Bank transfer (automatic)',
#   19.45,
#   '227.45',
#   'No'],
#  ['Female',
#   0,
#   'Yes',
#   'Yes',
#   48,
#   'Yes',
#   'No',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'Two year',
#   'No',
#   'Mailed check',
#   20.0,
#   '935.9',
#   'No'],
#  ['Male',
#   0,
#   'Yes',
#   'Yes',
#   71,
#   'Yes',
#   'Yes',
#   'DSL',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Two year',
#   'No',
#   'Bank transfer (automatic)',
#   86.85,
#   '6263.8',
#   'No'],
#  ['Female',
#   0,
#   'No',
#   'No',
#   64,
#   'Yes',
#   'Yes',
#   'No',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'No internet service',
#   'One year',
#   'No',
#   'Mailed check',
#   24.7,
#   '1642.75',
#   'No']]

# %%
feedback_scoring={
    "data":feedback_data
}

# %%
subscription.feedback_logging.store(feedback_scoring['data'])

# %%
subscription.feedback_logging.show_table()
# Out:
# <HTML>
#         <body>
#             <h3>Feedback_ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4 (binding_id=0ec1e966-ea03-41aa-9f88-9f83451cf1dc, subscription_id=ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4)</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>gender</th><th style='border: 1px solid #dddddd'>SeniorCitizen</th><th style='border: 1px solid #dddddd'>Partner</th><th style='border: 1px solid #dddddd'>Dependents</th><th style='border: 1px solid #dddddd'>tenure</th><th style='border: 1px solid #dddddd'>PhoneService</th><th style='border: 1px solid #dddddd'>MultipleLines</th><th style='border: 1px solid #dddddd'>InternetService</th><th style='border: 1px solid #dddddd'>OnlineSecurity</th><th style='border: 1px solid #dddddd'>OnlineBackup</th><th style='border: 1px solid #dddddd'>DeviceProtection</th><th style='border: 1px solid #dddddd'>TechSupport</th><th style='border: 1px solid #dddddd'>StreamingTV</th><th style='border: 1px solid #dddddd'>StreamingMovies</th><th style='border: 1px solid #dddddd'>Contract</th><th style='border: 1px solid #dddddd'>PaperlessBilling</th><th style='border: 1px solid #dddddd'>PaymentMethod</th><th style='border: 1px solid #dddddd'>MonthlyCharges</th><th style='border: 1px solid #dddddd'>TotalCharges</th><th style='border: 1px solid #dddddd'>Churn</th><th style='border: 1px solid #dddddd'>record_timestamp</th>
#                 <tr><td style='border: 1px solid #dddddd'>Male</td><td style='border: 1px solid #dddddd'>0</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>26</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>DSL</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>One year</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>Bank transfer (automatic)</td><td style='border: 1px solid #dddddd'>75.0</td><td style='border: 1px solid #dddddd'>1908.35</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>2020-08-25 18:41:06.475000+00:00</td></tr><tr><td style='border: 1px solid #dddddd'>Female</td><td style='border: 1px solid #dddddd'>0</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>38</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>DSL</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>One year</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>Bank transfer (automatic)</td><td style='border: 1px solid #dddddd'>84.1</td><td style='border: 1px solid #dddddd'>3187.65</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>2020-08-25 18:41:06.475000+00:00</td></tr><tr><td style='border: 1px solid #dddddd'>Male</td><td style='border: 1px solid #dddddd'>0</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>5</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>Two year</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>Mailed check</td><td style='border: 1px solid #dddddd'>20.45</td><td style='border: 1px solid #dddddd'>106.9</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>2020-08-25 18:41:06.475000+00:00</td></tr><tr><td style='border: 1px solid #dddddd'>Male</td><td style='border: 1px solid #dddddd'>0</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>1</td><td style='border: 1px solid #dddddd'>Yes</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>No</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>No internet service</td><td style='border: 1px solid #dddddd'>Month-to-month</td><td style='border: 1px ...

# %% [markdown]
# #### Run an inital quality test

# %%
run_details = subscription.quality_monitoring.run(background_mode=False)
# Out:
# ================================================================================
#
#  Waiting for end of quality monitoring run 045eae46-984d-4a43-8187-66be43c0d082
#
# ================================================================================
#
#
#
# initializing
# completed
#
# ---------------------------
#  Successfully finished run
# ---------------------------

# %%
subscription.quality_monitoring.show_table()
# Out:
# <HTML>
#         <body>
#             <h3>QualityMetrics (binding_id=0ec1e966-ea03-41aa-9f88-9f83451cf1dc, subscription_id=ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4)</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>ts</th><th style='border: 1px solid #dddddd'>id</th><th style='border: 1px solid #dddddd'>measurement_id</th><th style='border: 1px solid #dddddd'>value</th><th style='border: 1px solid #dddddd'>lower limit</th><th style='border: 1px solid #dddddd'>upper limit</th><th style='border: 1px solid #dddddd'>tags</th><th style='border: 1px solid #dddddd'>binding_id</th><th style='border: 1px solid #dddddd'>subscription_id</th><th style='border: 1px solid #dddddd'>deployment_id</th>
#                 <tr><td style='border: 1px solid #dddddd'>2020-08-25 18:41:20.294000+00:00</td><td style='border: 1px solid #dddddd'>true_positive_rate</td><td style='border: 1px solid #dddddd'>699c5344-cf44-4281-9a8f-053e9473d632</td><td style='border: 1px solid #dddddd'>0.8333333333333334</td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'>model_type: original</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td></tr><tr><td style='border: 1px solid #dddddd'>2020-08-25 18:41:20.294000+00:00</td><td style='border: 1px solid #dddddd'>area_under_roc</td><td style='border: 1px solid #dddddd'>699c5344-cf44-4281-9a8f-053e9473d632</td><td style='border: 1px solid #dddddd'>0.4166666666666667</td><td style='border: 1px solid #dddddd'>0.95</td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'>model_type: original</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td></tr><tr><td style='border: 1px solid #dddddd'>2020-08-25 18:41:20.294000+00:00</td><td style='border: 1px solid #dddddd'>precision</td><td style='border: 1px solid #dddddd'>699c5344-cf44-4281-9a8f-053e9473d632</td><td style='border: 1px solid #dddddd'>0.8823529411764706</td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'>model_type: original</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td></tr><tr><td style='border: 1px solid #dddddd'>2020-08-25 18:41:20.294000+00:00</td><td style='border: 1px solid #dddddd'>f1_measure</td><td style='border: 1px solid #dddddd'>699c5344-cf44-4281-9a8f-053e9473d632</td><td style='border: 1px solid #dddddd'>0.8571428571428571</td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'>model_type: original</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td></tr><tr><td style='border: 1px solid #dddddd'>2020-08-25 18:41:20.294000+00:00</td><td style='border: 1px solid #dddddd'>accuracy</td><td style='border: 1px solid #dddddd'>699c5344-cf44-4281-9a8f-053e9473d632</td><td style='border: 1px solid #dddddd'>0.75</td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'>model_type: original</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td></tr><tr><td style='border: 1px solid #dddddd'>2020-08-25 18:41:20.294000+00:00</td><td style='border: 1px solid #dddddd'>false_positive_rate</td><td style='border: 1px solid #dddddd'>699c5344-cf44-4281-9a8f-053e9473d632</td><td style='border: 1px solid #dddddd'>1.0</td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'></td><td style='border: 1px solid #dddddd'>model_type: original</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td></tr><tr><td style ...
#             </table>
#         </body>
#         </HTML>

# %%
# %matplotlib inline

quality_pd = subscription.quality_monitoring.get_table_content(format='pandas')
quality_pd.plot.barh(x='id', y='value');

# %% [markdown]
# ### 5.9 Setup the Fairness Monitors
#
# The code below configures fairness monitoring for our model. It turns on monitoring for two features, _conds(Weather Condition) and Traffic for the cell tower. In each case, we must specify:
#   * Which model feature to monitor
#   * One or more **majority** groups, which are values of that feature that we expect to receive a higher percentage of favorable outcomes
#   * One or more **minority** groups, which are values of that feature that we expect to receive a higher percentage of unfavorable outcomes
#   * The threshold at which we would like OpenScale to display an alert if the fairness measurement falls below (in this case, 95%)
#
# Additionally, we must specify which outcomes from the model are favourable outcomes, and which are unfavourable. We must also provide the number of records OpenScale will use to calculate the fairness score. In this case, OpenScale's fairness monitor will run hourly, but will not calculate a new fairness rating until at least 5 records have been added. Finally, to calculate fairness, OpenScale must perform some calculations on the training data, so we provide the dataframe containing the data.

# %% [markdown]
# ##### Congifure training data from the UI
# - Set up the training data connection from the DB2
# - Select Target label as Churn
# - Select all features except CustomerId

# %%
subscription.fairness_monitoring.enable(
            features=[
                Feature("gender", majority=['Male'], minority=['Female'], threshold=0.95),
                Feature("SeniorCitizen", majority=['0'], minority=['1'], threshold=0.95)
            ],
            favourable_classes=["Yes"],
            unfavourable_classes=["No"],
            min_records=50,
            training_data=df_data_1
        )

# %%
score2=X_test.head(20)

scoring_data2=list(list(x) for x in zip(*(score2[x].values.tolist() for x in score2.columns)))

fields2=list(X_test.columns)

job_payload2 = {
client.deployments.ScoringMetaNames.INPUT_DATA: [{
 'values': scoring_data2
}]
}

scoring_response2 = client.deployments.score(deployment_uid, job_payload2)


request_data2 = {
    "fields": fields,
    "values": scoring_data2
  }

records2 = [PayloadRecord(request=request_data2, response=scoring_response2, response_time=18), 
                PayloadRecord(request=request_data2, response=scoring_response2, response_time=12)]

subscription.payload_logging.store(records=records2)

# %%
time.sleep(10)

run_details = subscription.fairness_monitoring.run(background_mode=False)
# Out:
# =======================================================================
#
#  Counting bias for deployment_uid=0f430e90-d5ac-4610-8387-24e2b506a7aa
#
# =======================================================================
#
#
#
# FINISHED
#
# ---------------------------
#  Successfully finished run
# ---------------------------

# %%
time.sleep(5)

subscription.fairness_monitoring.show_table()
# Out:
# <HTML>
#         <body>
#             <h3>FairnessMetrics (binding_id=0ec1e966-ea03-41aa-9f88-9f83451cf1dc, subscription_id=ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4)</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>ts</th><th style='border: 1px solid #dddddd'>feature</th><th style='border: 1px solid #dddddd'>feature_value</th><th style='border: 1px solid #dddddd'>fairness_biased</th><th style='border: 1px solid #dddddd'>fairness_value</th><th style='border: 1px solid #dddddd'>fairness_fav_class</th><th style='border: 1px solid #dddddd'>binding_id</th><th style='border: 1px solid #dddddd'>subscription_id</th><th style='border: 1px solid #dddddd'>asset_revision</th><th style='border: 1px solid #dddddd'>deployment_id</th><th style='border: 1px solid #dddddd'>process</th>
#                 <tr><td style='border: 1px solid #dddddd'>2020-08-25 18:54:05.509466+00:00</td><td style='border: 1px solid #dddddd'>gender</td><td style='border: 1px solid #dddddd'>Female</td><td style='border: 1px solid #dddddd'>False</td><td style='border: 1px solid #dddddd'>1.0</td><td style='border: 1px solid #dddddd'>24.0</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td><td style='border: 1px solid #dddddd'></td></tr><tr><td style='border: 1px solid #dddddd'>2020-08-25 19:24:14.900918+00:00</td><td style='border: 1px solid #dddddd'>gender</td><td style='border: 1px solid #dddddd'>Female</td><td style='border: 1px solid #dddddd'>False</td><td style='border: 1px solid #dddddd'>1.0</td><td style='border: 1px solid #dddddd'>24.0</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td><td style='border: 1px solid #dddddd'></td></tr><tr><td style='border: 1px solid #dddddd'>2020-08-25 21:06:54.106288+00:00</td><td style='border: 1px solid #dddddd'>gender</td><td style='border: 1px solid #dddddd'>Female</td><td style='border: 1px solid #dddddd'>False</td><td style='border: 1px solid #dddddd'>1.0</td><td style='border: 1px solid #dddddd'>24.0</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td><td style='border: 1px solid #dddddd'></td></tr><tr><td style='border: 1px solid #dddddd'>2020-08-25 19:41:59.902467+00:00</td><td style='border: 1px solid #dddddd'>gender</td><td style='border: 1px solid #dddddd'>Female</td><td style='border: 1px solid #dddddd'>False</td><td style='border: 1px solid #dddddd'>1.0</td><td style='border: 1px solid #dddddd'>24.0</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td><td style='border: 1px solid #dddddd'></td></tr><tr><td style='border: 1px solid #dddddd'>2020-08-25 20:42:00.268054+00:00</td><td style='border: 1px solid #dddddd'>gender</td><td style='border: 1px solid #dddddd'>Female</td><td style='border: 1px solid #dddddd'>False</td><td style='border: 1px solid #dddddd'>1.0</td><td style='border: 1px solid #dddddd'>24.0</td><td style='border: 1px solid #dddddd'>0ec1e966-ea03-41aa-9f88-9f83451cf1dc</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>ecb22f99-963d-4c8c-bd8a-3d4b9154fcf4</td><td style='border: 1px solid #dddddd'>0f430e90-d5ac-4610-8387-24e2b506a7aa</td><td style='border: 1px solid #dddddd'></td></tr>
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# ## 6.0 Custom monitors and metrics

# %% [markdown]
# ### 6.1 Register custom monitor

# %%
def get_definition(monitor_name):
    monitors_definitions = ai_client.data_mart.monitors.get_details()['monitor_definitions']
    
    for definition in monitors_definitions:
        if monitor_name == definition['entity']['name']:
            return definition
    
    return None

# %% [markdown]
# Change `monitor_name` to something unique.

# %%
from ibm_ai_openscale.supporting_classes import Metric, Tag

monitor_name = 'custom_monitor_shivam'
metrics = [Metric(name='sensitivity', lower_limit_default=0.8), Metric(name='specificity', lower_limit_default=0.75)]
tags = [Tag(name='region', description='customer geographical region')]

existing_definition = get_definition(monitor_name)

if existing_definition is None:
    my_monitor = ai_client.data_mart.monitors.add(name=monitor_name, metrics=metrics, tags=tags)
else:
    my_monitor = existing_definition

# %% [markdown]
# ### 6.1.1 Get monitors uids and details

# %%
monitor_uid = my_monitor['metadata']['guid']

print(monitor_uid)

# %%
my_monitor = ai_client.data_mart.monitors.get_details(monitor_uid=monitor_uid)
print('monitor definition details', my_monitor)

# %% [markdown]
# ## 6.2 Enable custom monitor for subscription

# %%
from ibm_ai_openscale.supporting_classes import Threshold

thresholds = [Threshold(metric_uid='sensitivity', lower_limit=0.9)]
subscription.monitoring.enable(monitor_uid=monitor_uid, thresholds=thresholds)

# %% [markdown]
# ### 6.2.1 Get monitor configuration details

# %%
subscription.monitoring.get_details(monitor_uid=monitor_uid)

# %% [markdown]
# ## 6.3 Storing custom metrics

# %%
metrics = {"specificity": 0.78, "sensitivity": 0.67, "region": "us-south"}

subscription.monitoring.store_metrics(monitor_uid=monitor_uid, metrics=metrics)

# %% [markdown]
# ### 6.3.1 List and get custom metrics

# %%
subscription.monitoring.show_table(monitor_uid=monitor_uid)

# %%
custom_metrics = subscription.monitoring.get_metrics(monitor_uid=monitor_uid, deployment_uid='credit')
custom_metrics

# %%
custom_metrics_pandas = subscription.monitoring.get_table_content(monitor_uid=monitor_uid)

# %matplotlib inline
custom_metrics_pandas.plot.barh(x='id', y='value');

# %% [markdown]
# ## 7.0 Payload analytics

# %% [markdown]
# ### 7.1 Run data distributions calculation

# %%
from datetime import datetime

start_date = "2018-01-01T00:00:00.00Z"
end_date = datetime.utcnow().isoformat() + "Z"

sex_distribution = subscription.payload_logging.data_distribution.run(
            start_date=start_date,
            end_date=end_date,
            group=['prediction', 'gender'],
            agg=['count'])

# %% [markdown]
# ### 7.2 Get data distributions as pandas dataframe

# %%
sex_distribution_run_uid = sex_distribution['id']
distributions_pd = subscription.payload_logging.data_distribution.get_run_result(run_id=sex_distribution_run_uid, format='pandas')
distributions_pd

# %%
subscription.payload_logging.data_distribution.show_chart(sex_distribution_run_uid);

# %% [markdown]
# ## 8. Identify transactions for Explainability

# %%
from ibm_ai_openscale.supporting_classes import *
subscription.explainability.enable(training_data=df_data_1)

# %%
payload_data = subscription.payload_logging.get_table_content(limit=60)
payload_data.filter(items=['scoring_id', 'predictedLabel', 'probability'])
# Out:
#                                  scoring_id
# 0    c5e07a7b-7001-4144-ac9f-be508d383881-1
# 1    c5e07a7b-7001-4144-ac9f-be508d383881-2
# 2    c5e07a7b-7001-4144-ac9f-be508d383881-3
# 3    c5e07a7b-7001-4144-ac9f-be508d383881-4
# 4    c5e07a7b-7001-4144-ac9f-be508d383881-5
# 5    c5e07a7b-7001-4144-ac9f-be508d383881-6
# 6    c5e07a7b-7001-4144-ac9f-be508d383881-7
# 7    c5e07a7b-7001-4144-ac9f-be508d383881-8
# 8    c5e07a7b-7001-4144-ac9f-be508d383881-9
# 9   c5e07a7b-7001-4144-ac9f-be508d383881-10
# 10  c5e07a7b-7001-4144-ac9f-be508d383881-11
# 11  c5e07a7b-7001-4144-ac9f-be508d383881-12
# 12  c5e07a7b-7001-4144-ac9f-be508d383881-13
# 13  c5e07a7b-7001-4144-ac9f-be508d383881-14
# 14  c5e07a7b-7001-4144-ac9f-be508d383881-15
# 15  c5e07a7b-7001-4144-ac9f-be508d383881-16
# 16  c5e07a7b-7001-4144-ac9f-be508d383881-17
# 17  c5e07a7b-7001-4144-ac9f-be508d383881-18
# 18  c5e07a7b-7001-4144-ac9f-be508d383881-19
# 19  c5e07a7b-7001-4144-ac9f-be508d383881-20
# 20   3eaf7128-eb66-4dcb-be51-e24e6513bf24-1
# 21   3eaf7128-eb66-4dcb-be51-e24e6513bf24-2
# 22   3eaf7128-eb66-4dcb-be51-e24e6513bf24-3
# 23   3eaf7128-eb66-4dcb-be51-e24e6513bf24-4
# 24   3eaf7128-eb66-4dcb-be51-e24e6513bf24-5
# 25   3eaf7128-eb66-4dcb-be51-e24e6513bf24-6
# 26   3eaf7128-eb66-4dcb-be51-e24e6513bf24-7
# 27   3eaf7128-eb66-4dcb-be51-e24e6513bf24-8
# 28   3eaf7128-eb66-4dcb-be51-e24e6513bf24-9
# 29  3eaf7128-eb66-4dcb-be51-e24e6513bf24-10
# 30  3eaf7128-eb66-4dcb-be51-e24e6513bf24-11
# 31  3eaf7128-eb66-4dcb-be51-e24e6513bf24-12
# 32  3eaf7128-eb66-4dcb-be51-e24e6513bf24-13
# 33  3eaf7128-eb66-4dcb-be51-e24e6513bf24-14
# 34  3eaf7128-eb66-4dcb-be51-e24e6513bf24-15
# 35  3eaf7128-eb66-4dcb-be51-e24e6513bf24-16
# 36  3eaf7128-eb66-4dcb-be51-e24e6513bf24-17
# 37  3eaf7128-eb66-4dcb-be51-e24e6513bf24-18
# 38  3eaf7128-eb66-4dcb-be51-e24e6513bf24-19
# 39  3eaf7128-eb66-4dcb-be51-e24e6513bf24-20
# 40   619e004c-66e3-46ea-92b1-8aa55e5a3c6b-1
# 41   619e004c-66e3-46ea-92b1-8aa55e5a3c6b-2
# 42   619e004c-66e3-46ea-92b1-8aa55e5a3c6b-3
# 43   619e004c-66e3-46ea-92b1-8aa55e5a3c6b-4
# 44   619e004c-66e3-46ea-92b1-8aa55e5a3c6b-5
# 45   619e004c-66e3-46ea-92b1-8aa55e5a3c6b-6
# 46   619e004c-66e3-46ea-92b1-8aa55e5a3c6b-7
# 47   619e004c-66e3-46ea-92b1-8aa55e5a3c6b-8
# 48   619e004c-66e3-46ea-92b1-8aa55e5a3c6b-9
# 49  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-10
# 50  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-11
# 51  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-12
# 52  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-13
# 53  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-14
# 54  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-15
# 55  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-16
# 56  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-17
# 57  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-18
# 58  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-19
# 59  619e004c-66e3-46ea-92b1-8aa55e5a3c6b-20

# %% [markdown]
# ### Add some more Payload (Optional for populating your dashboard)
#
# If you wish to add some Payload Data. Take different sections of your test dataset and send to OpenScale as shown below-

# %%
score100=X_test.head(100)
score100

# %%
scoring_data100=list(list(x) for x in zip(*(score100[x].values.tolist() for x in score100.columns)))
scoring_data100

# %%
fields=list(X_test.columns)
print(len(fields))
fields, scoring_data100[0]

# %%
request_data100 = {
    "fields": fields,
    "values": scoring_data100
  }
request_data100

# %%
records100 = [PayloadRecord(request=request_data100, response=scoring_response, response_time=18), 
                PayloadRecord(request=request_data100, response=scoring_response, response_time=12)]

subscription.payload_logging.store(records=records100)
